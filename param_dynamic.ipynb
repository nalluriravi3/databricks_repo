# %%
#make parameters dynamic
dbutils.widgets.text("param_checkFileExists","")
dynamic_param=dbutils.widgets.get("param_checkFileExists")
print(dynamic_param)

# pass checkfile exists output into this note book
acceess_direct_value=dbutils.jobs.taskValues.get("check_file_exist","file_exist")
print(acceess_direct_value)
