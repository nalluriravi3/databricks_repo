# %%
server = "nalluri-server.database.windows.net"
database = "nalluri-db"
username = "nalluri"
password = "Tesco@201512"
jdbc_url = ("jdbc:sqlserver://nalluri-server.database.windows.net:1433;"
"database=nalluri-db;"
"encrypt=true;"
"trustServerCertificate=false;"
"hostNameInCertificate=*.database.windows.net;"
"loginTimeout=30;")

# %%
df = spark.read.jdbc(url=jdbc_url, table="dbo.customers", properties={"user": username, "password": password})
display(df)
