# %%
#DButils practise
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("/Volumes/workspace/default/bronze")

# %%
dbutils.fs.head("/Volumes/workspace/default/bronze/customer.csv",100)
# default data it can read upto 65536 bytes

# %%
#dbutils.fs.mkdirs("/Volumes/workspace/default/bronze/dbutildir")
dbutils.fs.ls("/Volumes/workspace/default/bronze")

# %%
dbutils.fs.cp("/Volumes/workspace/default/bronze/Book 12.csv","/Volumes/workspace/default/bronze/dbutildir/")

# %%
dbutils.fs.mv("/Volumes/workspace/default/bronze/dbutildir/","/Volumes/workspace/default/bronze",recurse=True)
